# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import pandas as pd
import os 
import numpy as np

dirname=os.path.dirname(os.path.abspath('__file__'))
filename=os.path.join(dirname,'recipesData.json')
df=pd.read_json(filename)

# %% [markdown]
# notebook

# %%
df.head()
# Out:
#                                     _id  \
# 0  {'$oid': '5fc3b88113f48bef0f019a31'}
# 1  {'$oid': '5fc3b88113f48bef0f019a33'}
# 2  {'$oid': '5fc3b88113f48bef0f019a36'}
# 3  {'$oid': '5fc3b88113f48bef0f019a37'}
# 4  {'$oid': '5fc3b88113f48bef0f019a39'}
#
#                                           ratingData  \
# 0  [{'rating': 5, 'count': 5, 'percentage': 50}, ...
# 1  [{'rating': 5, 'count': 8, 'percentage': 62}, ...
# 2  [{'rating': 5, 'count': 11, 'percentage': 58},...
# 3  [{'rating': 5, 'count': 8, 'percentage': 53}, ...
# 4  [{'rating': 5, 'count': 11, 'percentage': 61},...
#
#                                   name             datePublished  \
# 0  Hot Artichoke Dip with Green Chiles  2018-03-21T16:16:59.000Z
# 1            Party Plentiful Guacamole  2019-07-10T07:00:48.000Z
# 2                             Magaricz  2000-08-15T14:05:21.000Z
# 3                   Christmas Chip Dip  2018-03-21T16:17:41.000Z
# 4                        Christmas Dip  2019-04-02T06:50:26.000Z
#
#                                          description  recipeYield  \
# 0  Green chile peppers and garlic spice up this e...       4 cups
# 1  This is a recipe my Mom always brings to the f...       9 cups
# 2  This is my Russian grandmother's version of It...  10 servings
# 3  The simplest dip in festive colors for Christm...  16 servings
# 4  A creamy layered dip that looks beautiful, esp...       4 cups
#
#                                     recipeIngredient  \
# 0  [½ (16 ounce) jar creamy salad dressing, 1 clo...
# 1  [4 avocados - peeled, pitted and diced, 1 (8 o...
# 2  [¼ cup olive oil, 1 large eggplant, peeled and...
# 3  [2 cups softened cream cheese, 1 (6.5 ounce) j...
# 4  [1 (6 ounce) package dried cranberries, 1 cup ...
#
#                                   recipeInstructions  \
# 0  [{'text': 'Preheat oven to 350 degrees F (175 ...
# 1  [{'text': 'Place the avocados into a mixing bo...
# 2  [{'text': 'Place eggplant in a colander, light...
# 3  [{'text': 'Spread cream cheese in a clear, sha...
# 4  [{'text': 'Reserve 1 tablespoon of dried cranb...
#
#                                       recipeCategory  \
# 0  [Appetizers and Snack Recipes, Dips and Spread...
# 1  [Appetizers and Snack Recipes, Dips and Spread...
# 2                  [Side Dish, Vegetables, Eggplant]
# 3  [Appetizers and Snack Recipes, Dips and Spread...
# 4  [Appetizers and Snack Recipes, Dips and Spread...
#
#                                            nutrition  ...  \
# 0  {'calories': '47.4 calories', 'carbohydrateCon...  ...
# 1  {'calories': '86 calories', 'carbohydrateConte...  ...
# 2  {'calories': '76.6 calories', 'carbohydrateCon...  ...
# 3  {'calories': '117.8 calories', 'carbohydrateCo...  ...
# 4  {'calories': '142.1 calories', 'carbohydrateCo...  ...
#
#                                                 link    rating  \
# 0  https://www.allrecipes.com/recipe/23945/hot-ar...  4.400000
# 1  https://www.allrecipes.com/recipe/161178/party...  4.461538
# 2  https://www.allrecipes.com/recipe/20945/magaricz/  4.473684
# 3  https://www.allrecipes.com/recipe/24301/christ...  4.333333
# 4  https://www.allrecipes.com/recipe/165246/chris...  4.277778
#
#                                                  img prepTimeVal  cookTimeval  \
# 0  https://imagesvc.meredithcorp.io/v3/mm/image?u...           5           30
# 1  https://imagesvc.meredithcorp.io/v3/mm/image?u...          15            0
# 2  https://imagesvc.meredithcorp.io/v3/mm/image?u...          20           40
# 3  https://imagesvc.meredithcorp.io/v3/mm/image?u...           5            0
# 4  https://imagesvc.meredithcorp.io/v3/mm/image?u...          20            0
#
#   totalTimeVal  ratingCount  bestRating  worstRating  video
# 0           35           10           5            1    NaN
# 1           15           13           5            1    NaN
# 2          120           19           5            1    NaN
# 3            5           15           5            1    NaN
# 4          140           18           5            1    NaN
#
# [5 rows x 23 columns]

# %%
df=df[["rating","totalTimeVal"]]
#df.head()
df.sort_values(by=["totalTimeVal"])

from scipy import stats
df=df[(np.abs(stats.zscore(df)) < 3).all(axis=1)]
df=df[df.totalTimeVal>0]

#df.describe()

kmeans = KMeans(n_clusters=2, random_state=0).fit(df)
y_kmeans = kmeans.predict(df)
# centers = kmeans.cluster_centers_
plt.scatter(df.iloc[:, 1], df.iloc[:,0], c=y_kmeans, s=50, cmap="viridis")
# plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)
#y_kmeans
